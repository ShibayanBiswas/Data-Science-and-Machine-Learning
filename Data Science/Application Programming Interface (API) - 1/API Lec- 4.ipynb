# %%
import requests
import json

response = requests.get('https://api.openaq.org/v1/cities')
data = response.json()
data
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': 'CC BY 4.0d',
#   'website': 'api.openaq.org',
#   'page': 1,
#   'limit': 100,
#   'found': 3236},
#  'results': [{'country': 'US',
#    'name': '007',
#    'city': '007',
#    'count': 45303,
#    'locations': 7},
#   {'country': 'US',
#    'name': '019',
#    'city': '019',
#    'count': 2112,
#    'locations': 1},
#   {'country': 'US',
#    'name': '037',
#    'city': '037',
#    'count': 42684,
#    'locations': 23},
#   {'country': 'US',
#    'name': '039',
#    'city': '039',
#    'count': 1140,
#    'locations': 1},
#   {'country': 'US',
#    'name': '047',
#    'city': '047',
#    'count': 42429,
#    'locations': 4},
#   {'country': 'US',
#    'name': '051',
#    'city': '051',
#    'count': 990,
#    'locations': 7},
#   {'country': 'US',
#    'name': '077',
#    'city': '077',
#    'count': 9982,
#    'locations': 1},
#   {'country': 'CH',
#    'name': 'Aargau',
#    'city': 'Aargau',
#    'count': 12162,
#    'locations': 1},
#   {'country': 'MX',
#    'name': 'Abasolo',
#    'city': 'Abasolo',
#    'count': 1095,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ABBEVILLE',
#    'city': 'ABBEVILLE',
#    'count': 4619,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Aberdeen',
#    'city': 'Aberdeen',
#    'count': 174766,
#    'locations': 2},
#   {'country': 'GB',
#    'name': 'Aberdeen',
#    'city': 'Aberdeen',
#    'count': 635357,
#    'locations': 3},
#   {'country': 'CI',
#    'name': 'Abidjan',
#    'city': 'Abidjan',
#    'count': 69252,
#    'locations': 1},
#   {'country': 'AE',
#    'name': 'Abu Al Abyad',
#    'city': 'Abu Al Abyad',
#    'count': 10095,
#    'locations': 1},
#   {'country': 'AE',
#    'name': 'Abu Dhabi',
#    'city': 'Abu Dhabi',
#    'count': 284308,
#    'locations': 10},
#   {'country': 'GH',
#    'name': 'Accra',
#    'city': 'Accra',
#    'count': 67627,
#    'locations': 12},
#   {'country': 'ES',
#    'name': 'A Coruña',
#    'city': 'A Coruña',
#    'count': 1910977,
#    'locations': 24},
#   {'country': 'US',
#    'name': 'ADA',
#    'city': 'ADA',
#    'count': 80110,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ADAIR',
#    'city': 'ADAIR',
#    'count': 484988,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ADAMS',
#    'city': 'ADAMS',
#    'count': 175360,
#    'locations': 2},
#   {'country': 'TR',
#    'name': 'Adana',
#    'city': 'Adana',
#    'count': 752941,
#    'locations': 10},
#   {'country': 'ET',
#    'name': 'Addis Ababa',
#    'city': 'Addis Ababa',
#    'count': 239021,
#    'locations': 2},
#   {'country': 'AU',
#    'name': 'Adelaide',
#    'city': 'Adelaide',
#    'count': 516319,
#    'locations': 8},
#   {'country': 'TR',
#    'name': 'Adıyaman',
#    'city': 'Adıyaman',
#    'count': 8901,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Adrian',
#    'city': 'Adrian',
#    'count': 194225,
#    'locations': 1},
#   {'country': 'GB',
#    'name': 'Adur',
#    'city': 'Adur',
#    'count': 29061,
#    'locations': 1},
#   {'country': 'MK',
#    'name': 'Aerodrom Municipality',
#    'city': 'Aerodrom Municipality',
#    'count': 532112,
#    'locations': 1},
#   {'country': 'TR',
#    'name': 'Afyonkarahisar',
#    'city': 'Afyonkarahisar',
#    'count': 44274,
#    'locations': 3},
#   {'country': 'IN',
#    'name': 'Agartala',
#    'city': 'Agartala',
#    'count': 212295,
#    'locations': 4},
#   {'country': 'IN',
#    'name': 'Agra',
#    'city': 'Agra',
#    'count': 1290629,
#    'locations': 10},
#   {'country': 'TR',
#    'name': 'Ağrı',
#    'city': 'Ağrı',
#    'count': 443199,
#    'locations': 5},
#   {'country': 'MX',
#    'name': 'Aguascalientes',
#    'city': 'Aguascalientes',
#    'count': 79680,
#    'locations': 2},
#   {'country': 'IN',
#    'name': 'Ahmedabad',
#    'city': 'Ahmedabad',
#    'count': 1516674,
#    'locations': 18},
#   {'country': 'FR',
#    'name': 'Ain',
#    'city': 'Ain',
#    'count': 624990,
#    'locations': 2},
#   {'country': 'FR',
#    'name': 'AIR BREIZH',
#    'city': 'AIR BREIZH',
#    'count': 158918,
#    'locations': 5},
#   {'country': 'FR',
#    'name': 'AIR NORMAND',
#    'city': 'AIR NORMAND',
#    'count': 364,
#    'locations': 2},
#   {'country': 'FR',
#    'name': 'AIR PACA',
#    'city': 'AIR PACA',
#    'count': 16617,
#    'locations': 6},
#   {'country': 'FR',
#    'name': 'AIRPARIF',
#    'city': 'AIRPARIF',
#    'count': 170398,
#    'locations': 3},
#   {'country': 'FR',
#    'name': 'AIR PAYS DE LA LOIRE',
#    'city': 'AIR PAYS DE LA LOIRE',
#    'count': 924,
#    'locations': 1},
#   {'country': 'FR',
#    'name': 'AIR RHONE ALPES',
#    'city': 'AIR RHONE ALPES',
#    'count': 71,
#    'locations': 4},
#   {'country': 'FR',
#    'name': 'Aisne',
#    'city': 'Aisne',
#    'count': 410612,
#    'locations': 3},
#   {'country': 'IN',
#    'name': 'Aizawl',
#    'city': 'Aizawl',
#    'count': 239586,
#    'locations': 2},
#   {'country': 'IN',
#    'name': 'Ajmer',
#    'city': 'Ajmer',
#    'count': 831131,
#    'locations': 4},
#   {'country': 'US',
#    'name': 'Akron',
#    'city': 'Akron',
#    'count': 542443,
#    'locations': 4},
#   {'country': 'TR',
#    'name': 'Aksaray',
#    'city': 'Aksaray',
#    'count': 19767,
#    'locations': 1},
#   {'country': 'IS',
#    'name': 'Akureyri',
#    'city': 'Akureyri',
#    'count': 104499,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ALACHUA',
#    'city': 'ALACHUA',
#    'count': 43086,
#    'locations': 1},
#   {'country': 'AE',
#    'name': 'Al Ain',
#    'city': 'Al Ain',
#    'count': 63405,
#    'locations': 6},
#   {'country': 'US',
#    'name': 'ALAMEDA',
#    'city': 'ALAMEDA',
#    'count': 383763,
#    'locations': 1},
#   {'country': 'RO',
#    'name': 'Alba',
#    'city': 'Alba',
#    'count': 260381,
#    'locations': 3},
#   {'country': 'ES',
#    'name': 'Albacete',
#    'city': 'Albacete',
#    'count': 278586,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Albany',
#    'city': 'Albany',
#    'count': 84974,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Albany-Lebanon',
#    'city': 'Albany-Lebanon',
#    'count': 222705,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Albany-Schenectady-Troy',
#    'city': 'Albany-Schenectady-Troy',
#    'count': 276753,
#    'locations': 3},
#   {'country': 'CA',
#    'name': 'ALBERTA',
#    'city': 'ALBERTA',
#    'count': 5439627,
#    'locations': 42},
#   {'country': 'US',
#    'name': 'Albuquerque',
#    'city': 'Albuquerque',
#    'count': 2027471,
#    'locations': 7},
#   {'country': 'IT',
#    'name': 'Alessandria',
#    'city': 'Alessandria',
#    'count': 292729,
#    'locations': 3},
#   {'country': 'NO',
#    'name': 'Ålesund',
#    'city': 'Ålesund',
#    'count': 352196,
#    'locations': 3},
#   {'country': 'US',
#    'name': 'ALEXANDER',
#    'city': 'ALEXANDER',
#    'count': 119186,
#    'locations': 1},
#   {'country': 'IT',
#    'name': 'ALFONSINE',
#    'city': 'ALFONSINE',
#    'count': 105236,
#    'locations': 1},
#   {'country': 'ZA',
#    'name': 'Alfred Nzo',
#    'city': 'Alfred Nzo',
#    'count': 57429,
#    'locations': 86},
#   {'country': 'AU',
#    'name': 'Alfredton Fire',
#    'city': 'Alfredton Fire',
#    'count': 294,
#    'locations': 2},
#   {'country': 'ES',
#    'name': 'Alicante/Alacant',
#    'city': 'Alicante/Alacant',
#    'count': 1997481,
#    'locations': 10},
#   {'country': 'US',
#    'name': 'Allegan',
#    'city': 'Allegan',
#    'count': 125327,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ALLEGANY',
#    'city': 'ALLEGANY',
#    'count': 92984,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Allentown-Bethlehem-Easton',
#    'city': 'Allentown-Bethlehem-Easton',
#    'count': 444432,
#    'locations': 3},
#   {'country': 'FR',
#    'name': 'Allier',
#    'city': 'Allier',
#    'count': 405310,
#    'locations': 3},
#   {'country': 'ES',
#    'name': 'Almeria',
#    'city': 'Almeria',
#    'count': 1810728,
#    'locations': 1},
#   {'country': 'ES',
#    'name': 'Almería',
#    'city': 'Almería',
#    'count': 2890303,
#    'locations': 14},
#   {'country': 'MX',
#    'name': 'Almoloya de Juárez',
#    'city': 'Almoloya de Juárez',
#    'count': 6687,
#    'locations': 1},
#   {'country': 'FR',
#    'name': 'Alpes-de-Haute-Provence',
#    'city': 'Alpes-de-Haute-Provence',
#    'count': 575993,
#    'locations': 2},
#   {'country': 'FR',
#    'name': 'Alpes-Maritimes',
#    'city': 'Alpes-Maritimes',
#    'count': 1711498,
#    'locations': 10},
#   {'country': 'AE',
#    'name': 'Al Ruways Industrial City',
#    'city': 'Al Ruways Industrial City',
#    'count': 12732,
#    'locations': 1},
#   {'country': 'CL',
#    'name': 'Alto Hospicio',
#    'city': 'Alto Hospicio',
#    'count': 116278,
#    'locations': 3},
#   {'country': 'AU',
#    'name': 'Altona North',
#    'city': 'Altona North',
#    'count': 105060,
#    'locations': 1},
#   {'country': 'AU',
#    'name': 'Altona North 1',
#    'city': 'Altona North 1',
#    'count': 243,
#    'locations': 1},
#   {'country': 'AU',
#    'name': 'Altona North 2',
#    'city': 'Altona North 2',
#    'count': 234,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Altoona',
#    'city': 'Altoona',
#    'count': 211842,
#    'locations': 1},
#   {'country': 'MX',
#    'name': 'Álvaro Obregón',
#    'city': 'Álvaro Obregón',
#    'count': 70678,
#    'locations': 1},
#   {'country': 'IN',
#    'name': 'Alwar',
#    'city': 'Alwar',
#    'count': 867965,
#    'locations': 3},
#   {'country': 'LT',
#    'name': 'Alytus',
#    'city': 'Alytus',
#    'count': 27836,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'AMADOR',
#    'city': 'AMADOR',
#    'count': 107697,
#    'locations': 2},
#   {'country': 'IN',
#    'name': 'Amaravati',
#    'city': 'Amaravati',
#    'count': 700882,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Amarillo',
#    'city': 'Amarillo',
#    'count': 112528,
#    'locations': 2},
#   {'country': 'TR',
#    'name': 'Amasya',
#    'city': 'Amasya',
#    'count': 439988,
#    'locations': 5},
#   {'country': 'IN',
#    'name': 'Ambala',
#    'city': 'Ambala',
#    'count': 555836,
#    'locations': 2},
#   {'country': 'BR',
#    'name': 'Americana',
#    'city': 'Americana',
#    'count': 126541,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Americus',
#    'city': 'Americus',
#    'count': 83300,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Ames',
#    'city': 'Ames',
#    'count': 4773,
#    'locations': 1},
#   {'country': 'JO',
#    'name': 'Amman',
#    'city': 'Amman',
#    'count': 81558,
#    'locations': 1},
#   {'country': 'TH',
#    'name': 'Amnat Charoen',
#    'city': 'Amnat Charoen',
#    'count': 48756,
#    'locations': 3},
#   {'country': 'IN',
#    'name': 'Amritsar',
#    'city': 'Amritsar',
#    'count': 984244,
#    'locations': 2},
#   {'country': 'NL',
#    'name': 'Amsterdam',
#    'city': 'Amsterdam',
#    'count': 4251426,
#    'locations': 14},
#   {'country': 'AT',
#    'name': 'Amt der K�rntner Landesregierung',
#    'city': 'Amt der K�rntner Landesregierung',
#    'count': 6050,
#    'locations': 4},
#   {'country': 'AT',
#    'name': 'Amt der Nieder�sterreichischen Landesregierung',
#    'city': 'Amt der Nieder�sterreichischen Landesregierung',
#    'count': 7584,
#    'locations': 1},
#   {'country': 'AT',
#    'name': 'Amt der Ober�sterreichischen Landesregierung',
#    'city': 'Amt der Ober�sterreichischen Landesregierung',
#    'count': 13233,
#    'locations': 1},
#   {'country': 'AT',
#    'name': 'Amt der Salzburger Landesregierung',
#    'city': 'Amt der Salzburger Landesregierung',
#    'count': 11376,
#    'locations': 1},
#   {'country': 'AT',
#    'name': 'Amt der Steierm�rkischen Landesregierung',
#    'city': 'Amt der Steierm�rkischen Landesregierung',
#    'count': 34109,
#    'locations': 3},
#   {'country': 'IN',
#    'name': 'Anantapur',
#    'city': 'Anantapur',
#    'count': 10044,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Anchorage',
#    'city': 'Anchorage',
#    'count': 469828,
#    'locations': 3}]}

# %%
print(response.status_code)
print(response.encoding)
print(response.text)
print(response.url)
print(response.headers)
# Out:
# 200
# None
# {"meta":{"name":"openaq-api","license":"CC BY 4.0d","website":"api.openaq.org","page":1,"limit":100,"found":3236},"results":[{"country":"US","name":"007","city":"007","count":45303,"locations":7},{"country":"US","name":"019","city":"019","count":2112,"locations":1},{"country":"US","name":"037","city":"037","count":42684,"locations":23},{"country":"US","name":"039","city":"039","count":1140,"locations":1},{"country":"US","name":"047","city":"047","count":42429,"locations":4},{"country":"US","name":"051","city":"051","count":990,"locations":7},{"country":"US","name":"077","city":"077","count":9982,"locations":1},{"country":"CH","name":"Aargau","city":"Aargau","count":12162,"locations":1},{"country":"MX","name":"Abasolo","city":"Abasolo","count":1095,"locations":1},{"country":"US","name":"ABBEVILLE","city":"ABBEVILLE","count":4619,"locations":1},{"country":"US","name":"Aberdeen","city":"Aberdeen","count":174766,"locations":2},{"country":"GB","name":"Aberdeen","city":"Aberdeen","count":635357,"locations":3},{"country":"CI","name":"Abidjan","city":"Abidjan","count":69252,"locations":1},{"country":"AE","name":"Abu Al Abyad","city":"Abu Al Abyad","count":10095,"locations":1},{"country":"AE","name":"Abu Dhabi","city":"Abu Dhabi","count":284308,"locations":10},{"country":"GH","name":"Accra","city":"Accra","count":67627,"locations":12},{"country":"ES","name":"A Coruña","city":"A Coruña","count":1910977,"locations":24},{"country":"US","name":"ADA","city":"ADA","count":80110,"locations":1},{"country":"US","name":"ADAIR","city":"ADAIR","count":484988,"locations":1},{"country":"US","name":"ADAMS","city":"ADAMS","count":175360,"locations":2},{"country":"TR","name":"Adana","city":"Adana","count":752941,"locations":10},{"country":"ET","name":"Addis Ababa","city":"Addis Ababa","count":239021,"locations":2},{"country":"AU","name":"Adelaide","city":"Adelaide","count":516319,"locations":8},{"country":"TR","name":"Adıyaman","city":"Adıyaman","count":8901,"locations":1},{"country":"US","name":"Adrian","city":"Adrian","count":194225,"locations":1},{"country":"GB","name":"Adur","city":"Adur","count":29061,"locations":1},{"country":"MK","name":"Aerodrom Municipality","city":"Aerodrom Municipality","count":532112,"locations":1},{"country":"TR","name":"Afyonkarahisar","city":"Afyonkarahisar","count":44274,"locations":3},{"country":"IN","name":"Agartala","city":"Agartala","count":212295,"locations":4},{"country":"IN","name":"Agra","city":"Agra","count":1290629,"locations":10},{"country":"TR","name":"Ağrı","city":"Ağrı","count":443199,"locations":5},{"country":"MX","name":"Aguascalientes","city":"Aguascalientes","count":79680,"locations":2},{"country":"IN","name":"Ahmedabad","city":"Ahmedabad","count":1516674,"locations":18},{"country":"FR","name":"Ain","city":"Ain","count":624990,"locations":2},{"country":"FR","name":"AIR BREIZH","city":"AIR BREIZH","count":158918,"locations":5},{"country":"FR","name":"AIR NORMAND","city":"AIR NORMAND","count":364,"locations":2},{"country":"FR","name":"AIR PACA","city":"AIR PACA","count":16617,"locations":6},{"country":"FR","name":"AIRPARIF","city":"AIRPARIF","count":170398,"locations":3},{"country":"FR","name":"AIR PAYS DE LA LOIRE","city":"AIR PAYS DE LA LOIRE","count":924,"locations":1},{"country":"FR","name":"AIR RHONE ALPES","city":"AIR RHONE ALPES","count":71,"locations":4},{"country":"FR","name":"Aisne","city":"Aisne","count":410612,"locations":3},{"country":"IN","name":"Aizawl","city":"Aizawl","count":239586,"locations":2},{"country":"IN","name":"Ajmer","city":"Ajmer","count":831131,"locations":4},{"country":"US","name":"Akron","city":"Akron","count":542443,"locations":4},{"country":"TR","name":"Aksaray","city":"Aksaray","count":19767,"locations":1},{"country":"IS","name":"Akureyri","city":"Akureyri","count":104499,"locations":1},{"country":"US","name":"ALACHUA","city":"ALACHUA","count":43086,"locations":1},{"country":"AE","name":"Al Ain","city":"Al Ain","count":63405,"locations":6},{"country":"US","name":"ALAMEDA ...
# https://api.openaq.org/v1/cities
# {'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Date': 'Fri, 30 Dec 2022 19:07:31 GMT', 'Cache-Control': 'public, max-age=900', 'Apigw-Requestid': 'd-WGDglmIAMEc4Q=', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'X-Cache': 'Hit from cloudfront', 'Via': '1.1 ad49ff8ff03d68efb9eb939751d77c56.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'MIA3-P3', 'X-Amz-Cf-Id': 'bJAXJea2qkI1dR2esrjLwDgusVEAUSR4RuD0di1uQrUljMPn-xOyjg==', 'Age': '144'}

# %%
response = requests.get('https://api.openaq.org/v1/cities', params = {"Country" : "AE"})
data = response.json()
data
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': 'CC BY 4.0d',
#   'website': 'api.openaq.org',
#   'page': 1,
#   'limit': 100,
#   'found': 3236},
#  'results': [{'country': 'US',
#    'name': '007',
#    'city': '007',
#    'count': 45303,
#    'locations': 7},
#   {'country': 'US',
#    'name': '019',
#    'city': '019',
#    'count': 2112,
#    'locations': 1},
#   {'country': 'US',
#    'name': '037',
#    'city': '037',
#    'count': 42684,
#    'locations': 23},
#   {'country': 'US',
#    'name': '039',
#    'city': '039',
#    'count': 1140,
#    'locations': 1},
#   {'country': 'US',
#    'name': '047',
#    'city': '047',
#    'count': 42429,
#    'locations': 4},
#   {'country': 'US',
#    'name': '051',
#    'city': '051',
#    'count': 990,
#    'locations': 7},
#   {'country': 'US',
#    'name': '077',
#    'city': '077',
#    'count': 9982,
#    'locations': 1},
#   {'country': 'CH',
#    'name': 'Aargau',
#    'city': 'Aargau',
#    'count': 12162,
#    'locations': 1},
#   {'country': 'MX',
#    'name': 'Abasolo',
#    'city': 'Abasolo',
#    'count': 1095,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ABBEVILLE',
#    'city': 'ABBEVILLE',
#    'count': 4619,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Aberdeen',
#    'city': 'Aberdeen',
#    'count': 174766,
#    'locations': 2},
#   {'country': 'GB',
#    'name': 'Aberdeen',
#    'city': 'Aberdeen',
#    'count': 635357,
#    'locations': 3},
#   {'country': 'CI',
#    'name': 'Abidjan',
#    'city': 'Abidjan',
#    'count': 69252,
#    'locations': 1},
#   {'country': 'AE',
#    'name': 'Abu Al Abyad',
#    'city': 'Abu Al Abyad',
#    'count': 10095,
#    'locations': 1},
#   {'country': 'AE',
#    'name': 'Abu Dhabi',
#    'city': 'Abu Dhabi',
#    'count': 284308,
#    'locations': 10},
#   {'country': 'GH',
#    'name': 'Accra',
#    'city': 'Accra',
#    'count': 67627,
#    'locations': 12},
#   {'country': 'ES',
#    'name': 'A Coruña',
#    'city': 'A Coruña',
#    'count': 1910977,
#    'locations': 24},
#   {'country': 'US',
#    'name': 'ADA',
#    'city': 'ADA',
#    'count': 80110,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ADAIR',
#    'city': 'ADAIR',
#    'count': 484988,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ADAMS',
#    'city': 'ADAMS',
#    'count': 175360,
#    'locations': 2},
#   {'country': 'TR',
#    'name': 'Adana',
#    'city': 'Adana',
#    'count': 752941,
#    'locations': 10},
#   {'country': 'ET',
#    'name': 'Addis Ababa',
#    'city': 'Addis Ababa',
#    'count': 239021,
#    'locations': 2},
#   {'country': 'AU',
#    'name': 'Adelaide',
#    'city': 'Adelaide',
#    'count': 516319,
#    'locations': 8},
#   {'country': 'TR',
#    'name': 'Adıyaman',
#    'city': 'Adıyaman',
#    'count': 8901,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Adrian',
#    'city': 'Adrian',
#    'count': 194225,
#    'locations': 1},
#   {'country': 'GB',
#    'name': 'Adur',
#    'city': 'Adur',
#    'count': 29061,
#    'locations': 1},
#   {'country': 'MK',
#    'name': 'Aerodrom Municipality',
#    'city': 'Aerodrom Municipality',
#    'count': 532112,
#    'locations': 1},
#   {'country': 'TR',
#    'name': 'Afyonkarahisar',
#    'city': 'Afyonkarahisar',
#    'count': 44274,
#    'locations': 3},
#   {'country': 'IN',
#    'name': 'Agartala',
#    'city': 'Agartala',
#    'count': 212295,
#    'locations': 4},
#   {'country': 'IN',
#    'name': 'Agra',
#    'city': 'Agra',
#    'count': 1290629,
#    'locations': 10},
#   {'country': 'TR',
#    'name': 'Ağrı',
#    'city': 'Ağrı',
#    'count': 443199,
#    'locations': 5},
#   {'country': 'MX',
#    'name': 'Aguascalientes',
#    'city': 'Aguascalientes',
#    'count': 79680,
#    'locations': 2},
#   {'country': 'IN',
#    'name': 'Ahmedabad',
#    'city': 'Ahmedabad',
#    'count': 1516674,
#    'locations': 18},
#   {'country': 'FR',
#    'name': 'Ain',
#    'city': 'Ain',
#    'count': 624990,
#    'locations': 2},
#   {'country': 'FR',
#    'name': 'AIR BREIZH',
#    'city': 'AIR BREIZH',
#    'count': 158918,
#    'locations': 5},
#   {'country': 'FR',
#    'name': 'AIR NORMAND',
#    'city': 'AIR NORMAND',
#    'count': 364,
#    'locations': 2},
#   {'country': 'FR',
#    'name': 'AIR PACA',
#    'city': 'AIR PACA',
#    'count': 16617,
#    'locations': 6},
#   {'country': 'FR',
#    'name': 'AIRPARIF',
#    'city': 'AIRPARIF',
#    'count': 170398,
#    'locations': 3},
#   {'country': 'FR',
#    'name': 'AIR PAYS DE LA LOIRE',
#    'city': 'AIR PAYS DE LA LOIRE',
#    'count': 924,
#    'locations': 1},
#   {'country': 'FR',
#    'name': 'AIR RHONE ALPES',
#    'city': 'AIR RHONE ALPES',
#    'count': 71,
#    'locations': 4},
#   {'country': 'FR',
#    'name': 'Aisne',
#    'city': 'Aisne',
#    'count': 410612,
#    'locations': 3},
#   {'country': 'IN',
#    'name': 'Aizawl',
#    'city': 'Aizawl',
#    'count': 239586,
#    'locations': 2},
#   {'country': 'IN',
#    'name': 'Ajmer',
#    'city': 'Ajmer',
#    'count': 831131,
#    'locations': 4},
#   {'country': 'US',
#    'name': 'Akron',
#    'city': 'Akron',
#    'count': 542443,
#    'locations': 4},
#   {'country': 'TR',
#    'name': 'Aksaray',
#    'city': 'Aksaray',
#    'count': 19767,
#    'locations': 1},
#   {'country': 'IS',
#    'name': 'Akureyri',
#    'city': 'Akureyri',
#    'count': 104499,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ALACHUA',
#    'city': 'ALACHUA',
#    'count': 43086,
#    'locations': 1},
#   {'country': 'AE',
#    'name': 'Al Ain',
#    'city': 'Al Ain',
#    'count': 63405,
#    'locations': 6},
#   {'country': 'US',
#    'name': 'ALAMEDA',
#    'city': 'ALAMEDA',
#    'count': 383763,
#    'locations': 1},
#   {'country': 'RO',
#    'name': 'Alba',
#    'city': 'Alba',
#    'count': 260381,
#    'locations': 3},
#   {'country': 'ES',
#    'name': 'Albacete',
#    'city': 'Albacete',
#    'count': 278586,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Albany',
#    'city': 'Albany',
#    'count': 84974,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Albany-Lebanon',
#    'city': 'Albany-Lebanon',
#    'count': 222705,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Albany-Schenectady-Troy',
#    'city': 'Albany-Schenectady-Troy',
#    'count': 276753,
#    'locations': 3},
#   {'country': 'CA',
#    'name': 'ALBERTA',
#    'city': 'ALBERTA',
#    'count': 5439627,
#    'locations': 42},
#   {'country': 'US',
#    'name': 'Albuquerque',
#    'city': 'Albuquerque',
#    'count': 2027471,
#    'locations': 7},
#   {'country': 'IT',
#    'name': 'Alessandria',
#    'city': 'Alessandria',
#    'count': 292729,
#    'locations': 3},
#   {'country': 'NO',
#    'name': 'Ålesund',
#    'city': 'Ålesund',
#    'count': 352196,
#    'locations': 3},
#   {'country': 'US',
#    'name': 'ALEXANDER',
#    'city': 'ALEXANDER',
#    'count': 119186,
#    'locations': 1},
#   {'country': 'IT',
#    'name': 'ALFONSINE',
#    'city': 'ALFONSINE',
#    'count': 105236,
#    'locations': 1},
#   {'country': 'ZA',
#    'name': 'Alfred Nzo',
#    'city': 'Alfred Nzo',
#    'count': 57429,
#    'locations': 86},
#   {'country': 'AU',
#    'name': 'Alfredton Fire',
#    'city': 'Alfredton Fire',
#    'count': 294,
#    'locations': 2},
#   {'country': 'ES',
#    'name': 'Alicante/Alacant',
#    'city': 'Alicante/Alacant',
#    'count': 1997481,
#    'locations': 10},
#   {'country': 'US',
#    'name': 'Allegan',
#    'city': 'Allegan',
#    'count': 125327,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ALLEGANY',
#    'city': 'ALLEGANY',
#    'count': 92984,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Allentown-Bethlehem-Easton',
#    'city': 'Allentown-Bethlehem-Easton',
#    'count': 444432,
#    'locations': 3},
#   {'country': 'FR',
#    'name': 'Allier',
#    'city': 'Allier',
#    'count': 405310,
#    'locations': 3},
#   {'country': 'ES',
#    'name': 'Almeria',
#    'city': 'Almeria',
#    'count': 1810728,
#    'locations': 1},
#   {'country': 'ES',
#    'name': 'Almería',
#    'city': 'Almería',
#    'count': 2890303,
#    'locations': 14},
#   {'country': 'MX',
#    'name': 'Almoloya de Juárez',
#    'city': 'Almoloya de Juárez',
#    'count': 6687,
#    'locations': 1},
#   {'country': 'FR',
#    'name': 'Alpes-de-Haute-Provence',
#    'city': 'Alpes-de-Haute-Provence',
#    'count': 575993,
#    'locations': 2},
#   {'country': 'FR',
#    'name': 'Alpes-Maritimes',
#    'city': 'Alpes-Maritimes',
#    'count': 1711498,
#    'locations': 10},
#   {'country': 'AE',
#    'name': 'Al Ruways Industrial City',
#    'city': 'Al Ruways Industrial City',
#    'count': 12732,
#    'locations': 1},
#   {'country': 'CL',
#    'name': 'Alto Hospicio',
#    'city': 'Alto Hospicio',
#    'count': 116278,
#    'locations': 3},
#   {'country': 'AU',
#    'name': 'Altona North',
#    'city': 'Altona North',
#    'count': 105060,
#    'locations': 1},
#   {'country': 'AU',
#    'name': 'Altona North 1',
#    'city': 'Altona North 1',
#    'count': 243,
#    'locations': 1},
#   {'country': 'AU',
#    'name': 'Altona North 2',
#    'city': 'Altona North 2',
#    'count': 234,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Altoona',
#    'city': 'Altoona',
#    'count': 211842,
#    'locations': 1},
#   {'country': 'MX',
#    'name': 'Álvaro Obregón',
#    'city': 'Álvaro Obregón',
#    'count': 70678,
#    'locations': 1},
#   {'country': 'IN',
#    'name': 'Alwar',
#    'city': 'Alwar',
#    'count': 867965,
#    'locations': 3},
#   {'country': 'LT',
#    'name': 'Alytus',
#    'city': 'Alytus',
#    'count': 27836,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'AMADOR',
#    'city': 'AMADOR',
#    'count': 107697,
#    'locations': 2},
#   {'country': 'IN',
#    'name': 'Amaravati',
#    'city': 'Amaravati',
#    'count': 700882,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Amarillo',
#    'city': 'Amarillo',
#    'count': 112528,
#    'locations': 2},
#   {'country': 'TR',
#    'name': 'Amasya',
#    'city': 'Amasya',
#    'count': 439988,
#    'locations': 5},
#   {'country': 'IN',
#    'name': 'Ambala',
#    'city': 'Ambala',
#    'count': 555836,
#    'locations': 2},
#   {'country': 'BR',
#    'name': 'Americana',
#    'city': 'Americana',
#    'count': 126541,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Americus',
#    'city': 'Americus',
#    'count': 83300,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Ames',
#    'city': 'Ames',
#    'count': 4773,
#    'locations': 1},
#   {'country': 'JO',
#    'name': 'Amman',
#    'city': 'Amman',
#    'count': 81558,
#    'locations': 1},
#   {'country': 'TH',
#    'name': 'Amnat Charoen',
#    'city': 'Amnat Charoen',
#    'count': 48756,
#    'locations': 3},
#   {'country': 'IN',
#    'name': 'Amritsar',
#    'city': 'Amritsar',
#    'count': 984244,
#    'locations': 2},
#   {'country': 'NL',
#    'name': 'Amsterdam',
#    'city': 'Amsterdam',
#    'count': 4251426,
#    'locations': 14},
#   {'country': 'AT',
#    'name': 'Amt der K�rntner Landesregierung',
#    'city': 'Amt der K�rntner Landesregierung',
#    'count': 6050,
#    'locations': 4},
#   {'country': 'AT',
#    'name': 'Amt der Nieder�sterreichischen Landesregierung',
#    'city': 'Amt der Nieder�sterreichischen Landesregierung',
#    'count': 7584,
#    'locations': 1},
#   {'country': 'AT',
#    'name': 'Amt der Ober�sterreichischen Landesregierung',
#    'city': 'Amt der Ober�sterreichischen Landesregierung',
#    'count': 13233,
#    'locations': 1},
#   {'country': 'AT',
#    'name': 'Amt der Salzburger Landesregierung',
#    'city': 'Amt der Salzburger Landesregierung',
#    'count': 11376,
#    'locations': 1},
#   {'country': 'AT',
#    'name': 'Amt der Steierm�rkischen Landesregierung',
#    'city': 'Amt der Steierm�rkischen Landesregierung',
#    'count': 34109,
#    'locations': 3},
#   {'country': 'IN',
#    'name': 'Anantapur',
#    'city': 'Anantapur',
#    'count': 10044,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Anchorage',
#    'city': 'Anchorage',
#    'count': 469828,
#    'locations': 3}]}

# %%
print(response.status_code)
print(response.encoding)
print(response.text)
print(response.url)
print(response.headers)
# Out:
# 200
# None
# {"meta":{"name":"openaq-api","license":"CC BY 4.0d","website":"api.openaq.org","page":1,"limit":100,"found":3236},"results":[{"country":"US","name":"007","city":"007","count":45303,"locations":7},{"country":"US","name":"019","city":"019","count":2112,"locations":1},{"country":"US","name":"037","city":"037","count":42684,"locations":23},{"country":"US","name":"039","city":"039","count":1140,"locations":1},{"country":"US","name":"047","city":"047","count":42429,"locations":4},{"country":"US","name":"051","city":"051","count":990,"locations":7},{"country":"US","name":"077","city":"077","count":9982,"locations":1},{"country":"CH","name":"Aargau","city":"Aargau","count":12162,"locations":1},{"country":"MX","name":"Abasolo","city":"Abasolo","count":1095,"locations":1},{"country":"US","name":"ABBEVILLE","city":"ABBEVILLE","count":4619,"locations":1},{"country":"US","name":"Aberdeen","city":"Aberdeen","count":174766,"locations":2},{"country":"GB","name":"Aberdeen","city":"Aberdeen","count":635357,"locations":3},{"country":"CI","name":"Abidjan","city":"Abidjan","count":69252,"locations":1},{"country":"AE","name":"Abu Al Abyad","city":"Abu Al Abyad","count":10095,"locations":1},{"country":"AE","name":"Abu Dhabi","city":"Abu Dhabi","count":284308,"locations":10},{"country":"GH","name":"Accra","city":"Accra","count":67627,"locations":12},{"country":"ES","name":"A Coruña","city":"A Coruña","count":1910977,"locations":24},{"country":"US","name":"ADA","city":"ADA","count":80110,"locations":1},{"country":"US","name":"ADAIR","city":"ADAIR","count":484988,"locations":1},{"country":"US","name":"ADAMS","city":"ADAMS","count":175360,"locations":2},{"country":"TR","name":"Adana","city":"Adana","count":752941,"locations":10},{"country":"ET","name":"Addis Ababa","city":"Addis Ababa","count":239021,"locations":2},{"country":"AU","name":"Adelaide","city":"Adelaide","count":516319,"locations":8},{"country":"TR","name":"Adıyaman","city":"Adıyaman","count":8901,"locations":1},{"country":"US","name":"Adrian","city":"Adrian","count":194225,"locations":1},{"country":"GB","name":"Adur","city":"Adur","count":29061,"locations":1},{"country":"MK","name":"Aerodrom Municipality","city":"Aerodrom Municipality","count":532112,"locations":1},{"country":"TR","name":"Afyonkarahisar","city":"Afyonkarahisar","count":44274,"locations":3},{"country":"IN","name":"Agartala","city":"Agartala","count":212295,"locations":4},{"country":"IN","name":"Agra","city":"Agra","count":1290629,"locations":10},{"country":"TR","name":"Ağrı","city":"Ağrı","count":443199,"locations":5},{"country":"MX","name":"Aguascalientes","city":"Aguascalientes","count":79680,"locations":2},{"country":"IN","name":"Ahmedabad","city":"Ahmedabad","count":1516674,"locations":18},{"country":"FR","name":"Ain","city":"Ain","count":624990,"locations":2},{"country":"FR","name":"AIR BREIZH","city":"AIR BREIZH","count":158918,"locations":5},{"country":"FR","name":"AIR NORMAND","city":"AIR NORMAND","count":364,"locations":2},{"country":"FR","name":"AIR PACA","city":"AIR PACA","count":16617,"locations":6},{"country":"FR","name":"AIRPARIF","city":"AIRPARIF","count":170398,"locations":3},{"country":"FR","name":"AIR PAYS DE LA LOIRE","city":"AIR PAYS DE LA LOIRE","count":924,"locations":1},{"country":"FR","name":"AIR RHONE ALPES","city":"AIR RHONE ALPES","count":71,"locations":4},{"country":"FR","name":"Aisne","city":"Aisne","count":410612,"locations":3},{"country":"IN","name":"Aizawl","city":"Aizawl","count":239586,"locations":2},{"country":"IN","name":"Ajmer","city":"Ajmer","count":831131,"locations":4},{"country":"US","name":"Akron","city":"Akron","count":542443,"locations":4},{"country":"TR","name":"Aksaray","city":"Aksaray","count":19767,"locations":1},{"country":"IS","name":"Akureyri","city":"Akureyri","count":104499,"locations":1},{"country":"US","name":"ALACHUA","city":"ALACHUA","count":43086,"locations":1},{"country":"AE","name":"Al Ain","city":"Al Ain","count":63405,"locations":6},{"country":"US","name":"ALAMEDA ...
# https://api.openaq.org/v1/cities?Country=AE
# {'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Date': 'Fri, 30 Dec 2022 19:21:18 GMT', 'Cache-Control': 'public, max-age=900', 'Apigw-Requestid': 'd-YHNjyVIAMEMiA=', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'X-Cache': 'Miss from cloudfront', 'Via': '1.1 92b0aae16555572f654690c9e7efa280.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'MIA3-P3', 'X-Amz-Cf-Id': 'c9g31qsLvH89_xNl06Q9oT-XmYzj1W-OaaWDuBJabP62sASCRr3PMQ=='}

# %%
response = requests.get('https://api.openaq.org/v1/cities', params = {"Country" : "AE", "Limit" : 1})
data = response.json()
data
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': 'CC BY 4.0d',
#   'website': 'api.openaq.org',
#   'page': 1,
#   'limit': 100,
#   'found': 3236},
#  'results': [{'country': 'US',
#    'name': '007',
#    'city': '007',
#    'count': 45303,
#    'locations': 7},
#   {'country': 'US',
#    'name': '019',
#    'city': '019',
#    'count': 2112,
#    'locations': 1},
#   {'country': 'US',
#    'name': '037',
#    'city': '037',
#    'count': 42684,
#    'locations': 23},
#   {'country': 'US',
#    'name': '039',
#    'city': '039',
#    'count': 1140,
#    'locations': 1},
#   {'country': 'US',
#    'name': '047',
#    'city': '047',
#    'count': 42429,
#    'locations': 4},
#   {'country': 'US',
#    'name': '051',
#    'city': '051',
#    'count': 990,
#    'locations': 7},
#   {'country': 'US',
#    'name': '077',
#    'city': '077',
#    'count': 9982,
#    'locations': 1},
#   {'country': 'CH',
#    'name': 'Aargau',
#    'city': 'Aargau',
#    'count': 12162,
#    'locations': 1},
#   {'country': 'MX',
#    'name': 'Abasolo',
#    'city': 'Abasolo',
#    'count': 1095,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ABBEVILLE',
#    'city': 'ABBEVILLE',
#    'count': 4619,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Aberdeen',
#    'city': 'Aberdeen',
#    'count': 174766,
#    'locations': 2},
#   {'country': 'GB',
#    'name': 'Aberdeen',
#    'city': 'Aberdeen',
#    'count': 635357,
#    'locations': 3},
#   {'country': 'CI',
#    'name': 'Abidjan',
#    'city': 'Abidjan',
#    'count': 69252,
#    'locations': 1},
#   {'country': 'AE',
#    'name': 'Abu Al Abyad',
#    'city': 'Abu Al Abyad',
#    'count': 10095,
#    'locations': 1},
#   {'country': 'AE',
#    'name': 'Abu Dhabi',
#    'city': 'Abu Dhabi',
#    'count': 284308,
#    'locations': 10},
#   {'country': 'GH',
#    'name': 'Accra',
#    'city': 'Accra',
#    'count': 67627,
#    'locations': 12},
#   {'country': 'ES',
#    'name': 'A Coruña',
#    'city': 'A Coruña',
#    'count': 1910977,
#    'locations': 24},
#   {'country': 'US',
#    'name': 'ADA',
#    'city': 'ADA',
#    'count': 80110,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ADAIR',
#    'city': 'ADAIR',
#    'count': 484988,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ADAMS',
#    'city': 'ADAMS',
#    'count': 175360,
#    'locations': 2},
#   {'country': 'TR',
#    'name': 'Adana',
#    'city': 'Adana',
#    'count': 752941,
#    'locations': 10},
#   {'country': 'ET',
#    'name': 'Addis Ababa',
#    'city': 'Addis Ababa',
#    'count': 239021,
#    'locations': 2},
#   {'country': 'AU',
#    'name': 'Adelaide',
#    'city': 'Adelaide',
#    'count': 516319,
#    'locations': 8},
#   {'country': 'TR',
#    'name': 'Adıyaman',
#    'city': 'Adıyaman',
#    'count': 8901,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Adrian',
#    'city': 'Adrian',
#    'count': 194225,
#    'locations': 1},
#   {'country': 'GB',
#    'name': 'Adur',
#    'city': 'Adur',
#    'count': 29061,
#    'locations': 1},
#   {'country': 'MK',
#    'name': 'Aerodrom Municipality',
#    'city': 'Aerodrom Municipality',
#    'count': 532112,
#    'locations': 1},
#   {'country': 'TR',
#    'name': 'Afyonkarahisar',
#    'city': 'Afyonkarahisar',
#    'count': 44274,
#    'locations': 3},
#   {'country': 'IN',
#    'name': 'Agartala',
#    'city': 'Agartala',
#    'count': 212295,
#    'locations': 4},
#   {'country': 'IN',
#    'name': 'Agra',
#    'city': 'Agra',
#    'count': 1290629,
#    'locations': 10},
#   {'country': 'TR',
#    'name': 'Ağrı',
#    'city': 'Ağrı',
#    'count': 443199,
#    'locations': 5},
#   {'country': 'MX',
#    'name': 'Aguascalientes',
#    'city': 'Aguascalientes',
#    'count': 79680,
#    'locations': 2},
#   {'country': 'IN',
#    'name': 'Ahmedabad',
#    'city': 'Ahmedabad',
#    'count': 1516674,
#    'locations': 18},
#   {'country': 'FR',
#    'name': 'Ain',
#    'city': 'Ain',
#    'count': 624990,
#    'locations': 2},
#   {'country': 'FR',
#    'name': 'AIR BREIZH',
#    'city': 'AIR BREIZH',
#    'count': 158918,
#    'locations': 5},
#   {'country': 'FR',
#    'name': 'AIR NORMAND',
#    'city': 'AIR NORMAND',
#    'count': 364,
#    'locations': 2},
#   {'country': 'FR',
#    'name': 'AIR PACA',
#    'city': 'AIR PACA',
#    'count': 16617,
#    'locations': 6},
#   {'country': 'FR',
#    'name': 'AIRPARIF',
#    'city': 'AIRPARIF',
#    'count': 170398,
#    'locations': 3},
#   {'country': 'FR',
#    'name': 'AIR PAYS DE LA LOIRE',
#    'city': 'AIR PAYS DE LA LOIRE',
#    'count': 924,
#    'locations': 1},
#   {'country': 'FR',
#    'name': 'AIR RHONE ALPES',
#    'city': 'AIR RHONE ALPES',
#    'count': 71,
#    'locations': 4},
#   {'country': 'FR',
#    'name': 'Aisne',
#    'city': 'Aisne',
#    'count': 410612,
#    'locations': 3},
#   {'country': 'IN',
#    'name': 'Aizawl',
#    'city': 'Aizawl',
#    'count': 239586,
#    'locations': 2},
#   {'country': 'IN',
#    'name': 'Ajmer',
#    'city': 'Ajmer',
#    'count': 831131,
#    'locations': 4},
#   {'country': 'US',
#    'name': 'Akron',
#    'city': 'Akron',
#    'count': 542443,
#    'locations': 4},
#   {'country': 'TR',
#    'name': 'Aksaray',
#    'city': 'Aksaray',
#    'count': 19767,
#    'locations': 1},
#   {'country': 'IS',
#    'name': 'Akureyri',
#    'city': 'Akureyri',
#    'count': 104499,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ALACHUA',
#    'city': 'ALACHUA',
#    'count': 43086,
#    'locations': 1},
#   {'country': 'AE',
#    'name': 'Al Ain',
#    'city': 'Al Ain',
#    'count': 63405,
#    'locations': 6},
#   {'country': 'US',
#    'name': 'ALAMEDA',
#    'city': 'ALAMEDA',
#    'count': 383763,
#    'locations': 1},
#   {'country': 'RO',
#    'name': 'Alba',
#    'city': 'Alba',
#    'count': 260381,
#    'locations': 3},
#   {'country': 'ES',
#    'name': 'Albacete',
#    'city': 'Albacete',
#    'count': 278586,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Albany',
#    'city': 'Albany',
#    'count': 84974,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Albany-Lebanon',
#    'city': 'Albany-Lebanon',
#    'count': 222705,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Albany-Schenectady-Troy',
#    'city': 'Albany-Schenectady-Troy',
#    'count': 276753,
#    'locations': 3},
#   {'country': 'CA',
#    'name': 'ALBERTA',
#    'city': 'ALBERTA',
#    'count': 5439627,
#    'locations': 42},
#   {'country': 'US',
#    'name': 'Albuquerque',
#    'city': 'Albuquerque',
#    'count': 2027471,
#    'locations': 7},
#   {'country': 'IT',
#    'name': 'Alessandria',
#    'city': 'Alessandria',
#    'count': 292729,
#    'locations': 3},
#   {'country': 'NO',
#    'name': 'Ålesund',
#    'city': 'Ålesund',
#    'count': 352196,
#    'locations': 3},
#   {'country': 'US',
#    'name': 'ALEXANDER',
#    'city': 'ALEXANDER',
#    'count': 119186,
#    'locations': 1},
#   {'country': 'IT',
#    'name': 'ALFONSINE',
#    'city': 'ALFONSINE',
#    'count': 105236,
#    'locations': 1},
#   {'country': 'ZA',
#    'name': 'Alfred Nzo',
#    'city': 'Alfred Nzo',
#    'count': 57429,
#    'locations': 86},
#   {'country': 'AU',
#    'name': 'Alfredton Fire',
#    'city': 'Alfredton Fire',
#    'count': 294,
#    'locations': 2},
#   {'country': 'ES',
#    'name': 'Alicante/Alacant',
#    'city': 'Alicante/Alacant',
#    'count': 1997481,
#    'locations': 10},
#   {'country': 'US',
#    'name': 'Allegan',
#    'city': 'Allegan',
#    'count': 125327,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'ALLEGANY',
#    'city': 'ALLEGANY',
#    'count': 92984,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Allentown-Bethlehem-Easton',
#    'city': 'Allentown-Bethlehem-Easton',
#    'count': 444432,
#    'locations': 3},
#   {'country': 'FR',
#    'name': 'Allier',
#    'city': 'Allier',
#    'count': 405310,
#    'locations': 3},
#   {'country': 'ES',
#    'name': 'Almeria',
#    'city': 'Almeria',
#    'count': 1810728,
#    'locations': 1},
#   {'country': 'ES',
#    'name': 'Almería',
#    'city': 'Almería',
#    'count': 2890303,
#    'locations': 14},
#   {'country': 'MX',
#    'name': 'Almoloya de Juárez',
#    'city': 'Almoloya de Juárez',
#    'count': 6687,
#    'locations': 1},
#   {'country': 'FR',
#    'name': 'Alpes-de-Haute-Provence',
#    'city': 'Alpes-de-Haute-Provence',
#    'count': 575993,
#    'locations': 2},
#   {'country': 'FR',
#    'name': 'Alpes-Maritimes',
#    'city': 'Alpes-Maritimes',
#    'count': 1711498,
#    'locations': 10},
#   {'country': 'AE',
#    'name': 'Al Ruways Industrial City',
#    'city': 'Al Ruways Industrial City',
#    'count': 12732,
#    'locations': 1},
#   {'country': 'CL',
#    'name': 'Alto Hospicio',
#    'city': 'Alto Hospicio',
#    'count': 116278,
#    'locations': 3},
#   {'country': 'AU',
#    'name': 'Altona North',
#    'city': 'Altona North',
#    'count': 105060,
#    'locations': 1},
#   {'country': 'AU',
#    'name': 'Altona North 1',
#    'city': 'Altona North 1',
#    'count': 243,
#    'locations': 1},
#   {'country': 'AU',
#    'name': 'Altona North 2',
#    'city': 'Altona North 2',
#    'count': 234,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Altoona',
#    'city': 'Altoona',
#    'count': 211842,
#    'locations': 1},
#   {'country': 'MX',
#    'name': 'Álvaro Obregón',
#    'city': 'Álvaro Obregón',
#    'count': 70678,
#    'locations': 1},
#   {'country': 'IN',
#    'name': 'Alwar',
#    'city': 'Alwar',
#    'count': 867965,
#    'locations': 3},
#   {'country': 'LT',
#    'name': 'Alytus',
#    'city': 'Alytus',
#    'count': 27836,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'AMADOR',
#    'city': 'AMADOR',
#    'count': 107697,
#    'locations': 2},
#   {'country': 'IN',
#    'name': 'Amaravati',
#    'city': 'Amaravati',
#    'count': 700882,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Amarillo',
#    'city': 'Amarillo',
#    'count': 112528,
#    'locations': 2},
#   {'country': 'TR',
#    'name': 'Amasya',
#    'city': 'Amasya',
#    'count': 439988,
#    'locations': 5},
#   {'country': 'IN',
#    'name': 'Ambala',
#    'city': 'Ambala',
#    'count': 555836,
#    'locations': 2},
#   {'country': 'BR',
#    'name': 'Americana',
#    'city': 'Americana',
#    'count': 126541,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Americus',
#    'city': 'Americus',
#    'count': 83300,
#    'locations': 1},
#   {'country': 'US',
#    'name': 'Ames',
#    'city': 'Ames',
#    'count': 4773,
#    'locations': 1},
#   {'country': 'JO',
#    'name': 'Amman',
#    'city': 'Amman',
#    'count': 81558,
#    'locations': 1},
#   {'country': 'TH',
#    'name': 'Amnat Charoen',
#    'city': 'Amnat Charoen',
#    'count': 48756,
#    'locations': 3},
#   {'country': 'IN',
#    'name': 'Amritsar',
#    'city': 'Amritsar',
#    'count': 984244,
#    'locations': 2},
#   {'country': 'NL',
#    'name': 'Amsterdam',
#    'city': 'Amsterdam',
#    'count': 4251426,
#    'locations': 14},
#   {'country': 'AT',
#    'name': 'Amt der K�rntner Landesregierung',
#    'city': 'Amt der K�rntner Landesregierung',
#    'count': 6050,
#    'locations': 4},
#   {'country': 'AT',
#    'name': 'Amt der Nieder�sterreichischen Landesregierung',
#    'city': 'Amt der Nieder�sterreichischen Landesregierung',
#    'count': 7584,
#    'locations': 1},
#   {'country': 'AT',
#    'name': 'Amt der Ober�sterreichischen Landesregierung',
#    'city': 'Amt der Ober�sterreichischen Landesregierung',
#    'count': 13233,
#    'locations': 1},
#   {'country': 'AT',
#    'name': 'Amt der Salzburger Landesregierung',
#    'city': 'Amt der Salzburger Landesregierung',
#    'count': 11376,
#    'locations': 1},
#   {'country': 'AT',
#    'name': 'Amt der Steierm�rkischen Landesregierung',
#    'city': 'Amt der Steierm�rkischen Landesregierung',
#    'count': 34109,
#    'locations': 3},
#   {'country': 'IN',
#    'name': 'Anantapur',
#    'city': 'Anantapur',
#    'count': 10044,
#    'locations': 2},
#   {'country': 'US',
#    'name': 'Anchorage',
#    'city': 'Anchorage',
#    'count': 469828,
#    'locations': 3}]}

# %%
print(response.status_code)
print(response.encoding)
print(response.text)
print(response.url)
print(response.headers)
# Out:
# 200
# None
# {"meta":{"name":"openaq-api","license":"CC BY 4.0d","website":"api.openaq.org","page":1,"limit":100,"found":3236},"results":[{"country":"US","name":"007","city":"007","count":45303,"locations":7},{"country":"US","name":"019","city":"019","count":2112,"locations":1},{"country":"US","name":"037","city":"037","count":42684,"locations":23},{"country":"US","name":"039","city":"039","count":1140,"locations":1},{"country":"US","name":"047","city":"047","count":42429,"locations":4},{"country":"US","name":"051","city":"051","count":990,"locations":7},{"country":"US","name":"077","city":"077","count":9982,"locations":1},{"country":"CH","name":"Aargau","city":"Aargau","count":12162,"locations":1},{"country":"MX","name":"Abasolo","city":"Abasolo","count":1095,"locations":1},{"country":"US","name":"ABBEVILLE","city":"ABBEVILLE","count":4619,"locations":1},{"country":"US","name":"Aberdeen","city":"Aberdeen","count":174766,"locations":2},{"country":"GB","name":"Aberdeen","city":"Aberdeen","count":635357,"locations":3},{"country":"CI","name":"Abidjan","city":"Abidjan","count":69252,"locations":1},{"country":"AE","name":"Abu Al Abyad","city":"Abu Al Abyad","count":10095,"locations":1},{"country":"AE","name":"Abu Dhabi","city":"Abu Dhabi","count":284308,"locations":10},{"country":"GH","name":"Accra","city":"Accra","count":67627,"locations":12},{"country":"ES","name":"A Coruña","city":"A Coruña","count":1910977,"locations":24},{"country":"US","name":"ADA","city":"ADA","count":80110,"locations":1},{"country":"US","name":"ADAIR","city":"ADAIR","count":484988,"locations":1},{"country":"US","name":"ADAMS","city":"ADAMS","count":175360,"locations":2},{"country":"TR","name":"Adana","city":"Adana","count":752941,"locations":10},{"country":"ET","name":"Addis Ababa","city":"Addis Ababa","count":239021,"locations":2},{"country":"AU","name":"Adelaide","city":"Adelaide","count":516319,"locations":8},{"country":"TR","name":"Adıyaman","city":"Adıyaman","count":8901,"locations":1},{"country":"US","name":"Adrian","city":"Adrian","count":194225,"locations":1},{"country":"GB","name":"Adur","city":"Adur","count":29061,"locations":1},{"country":"MK","name":"Aerodrom Municipality","city":"Aerodrom Municipality","count":532112,"locations":1},{"country":"TR","name":"Afyonkarahisar","city":"Afyonkarahisar","count":44274,"locations":3},{"country":"IN","name":"Agartala","city":"Agartala","count":212295,"locations":4},{"country":"IN","name":"Agra","city":"Agra","count":1290629,"locations":10},{"country":"TR","name":"Ağrı","city":"Ağrı","count":443199,"locations":5},{"country":"MX","name":"Aguascalientes","city":"Aguascalientes","count":79680,"locations":2},{"country":"IN","name":"Ahmedabad","city":"Ahmedabad","count":1516674,"locations":18},{"country":"FR","name":"Ain","city":"Ain","count":624990,"locations":2},{"country":"FR","name":"AIR BREIZH","city":"AIR BREIZH","count":158918,"locations":5},{"country":"FR","name":"AIR NORMAND","city":"AIR NORMAND","count":364,"locations":2},{"country":"FR","name":"AIR PACA","city":"AIR PACA","count":16617,"locations":6},{"country":"FR","name":"AIRPARIF","city":"AIRPARIF","count":170398,"locations":3},{"country":"FR","name":"AIR PAYS DE LA LOIRE","city":"AIR PAYS DE LA LOIRE","count":924,"locations":1},{"country":"FR","name":"AIR RHONE ALPES","city":"AIR RHONE ALPES","count":71,"locations":4},{"country":"FR","name":"Aisne","city":"Aisne","count":410612,"locations":3},{"country":"IN","name":"Aizawl","city":"Aizawl","count":239586,"locations":2},{"country":"IN","name":"Ajmer","city":"Ajmer","count":831131,"locations":4},{"country":"US","name":"Akron","city":"Akron","count":542443,"locations":4},{"country":"TR","name":"Aksaray","city":"Aksaray","count":19767,"locations":1},{"country":"IS","name":"Akureyri","city":"Akureyri","count":104499,"locations":1},{"country":"US","name":"ALACHUA","city":"ALACHUA","count":43086,"locations":1},{"country":"AE","name":"Al Ain","city":"Al Ain","count":63405,"locations":6},{"country":"US","name":"ALAMEDA ...
# https://api.openaq.org/v1/cities?Country=AE&Limit=1
# {'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Date': 'Fri, 30 Dec 2022 19:23:10 GMT', 'Cache-Control': 'public, max-age=900', 'Apigw-Requestid': 'd-YYuivKIAMEM4g=', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'X-Cache': 'Miss from cloudfront', 'Via': '1.1 fb4c985c6e0ddb6f82a2dffdde62d23e.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'MIA3-P3', 'X-Amz-Cf-Id': 'zsq5b4fNNOUdHPk2kESOR-rIhCIY9VR8KdrG5T7kGJ28OFgCk0TQUg=='}
