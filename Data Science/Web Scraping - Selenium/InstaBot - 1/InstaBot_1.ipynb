# %% [markdown]
# Your friend has opened a new Food Blogging handle on Instagram and wants to get famous. He wants to follow a lot of people so that he can get noticed quickly but it is a tedious task so he asks you to help him. As you have just learned automation using Selenium, you decided to help him by creating an Instagram Bot. You need to create different functions for each task.

# %%
from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import TimeoutException
from bs4 import BeautifulSoup
import time

# %% [markdown]
# Login to your Instagram Handle : Submit with sample username and password

# %%
driver = webdriver.Chrome(executable_path="/path/to/chromedriver")
driver.maximize_window()
driver.get('https://www.instagram.com/')

username = 'Shibayan_Biswas'
password = 'ae21b109'

wait = WebDriverWait(driver, 10)
# Out:
# C:\Users\SHIBAYAN BISWAS\AppData\Local\Temp\ipykernel_9892\3495466950.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="/path/to/chromedriver")

# %%
def LogIn(username, password):
    try :
        #locating username textbox and sending username
        user_name = wait.until(EC.presence_of_element_located((By.NAME, 'username')))
        user_name.send_keys(username)
        #locating password box and sending password
        pass_word = wait.until(EC.presence_of_element_located((By.NAME, 'password')))
        pass_word.send_keys(password)
        #locating login button 
        button = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@id="loginForm"]/div[1]/div[3]/button/div')))
        button.submit()
        
    except TimeoutException :
        pass
        

#Login to your Instagram Handle
LogIn(username, password)

# %% [markdown]
# Type for “food” in search bar and print all the names of the Instagram Handles that are displayed in list after typing “food”.
#
# Note : Make sure to avoid printing hashtags

# %%
wait.until(EC.element_to_be_clickable((By.XPATH, "//button[contains(text(), 'Not Now')]"))).click()
wait.until(EC.element_to_be_clickable((By.XPATH, "//button[contains(text(), 'Not Now')]"))).click()
driver.find_element(By.CLASS_NAME, '_aacl._aacp._aacu._aacx._aada').click()
driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[1]/div/div/div/div[1]/div[1]/div[1]/div/div/div[2]/div/div/div[2]/div[1]/div/input').send_keys("food")

# %%
search_handle = driver.find_elements(By.CLASS_NAME, '_aacl._aaco._aacw._aacx._aad6')

for i in search_handle:
    if len(i.text) > 0 and i.text[0] != '#':
        print(i.text)
# Out:
# food_impramation
# malangfoodies
# albaik
# foodie_incarnate
# usa.explores
# balifood
# food
# topfoodbcn
# foodporn
# foodhunter_sabu
# foodgod
# foodie_malabariii
# germany.explores
# streetfoodrecipe
# aa.kabayan
# uk.explores
# foodiaz
# food.darzee
# healthy.foods.today
# poland.explore
# prowlfood
# eatguide
# maldives.explores
# starvingtime
# fao
# dyodoran
# jktfooddestination
# foodfusionpk
# insiderfood
# philippines.explores
# fitness_food_motivation
# greece.explores
# sana
# china.travels
# foodfromtheheart
# jktfoodbang
# peoplefood
# foodbible
# healthyfood.facts
# foodcreators
# southkorea.explores
# fooddotcom
# meghnasfoodmagic
# delectable__crunch
# foodie.munchies
# villagefoodchannel_official
# delhifoodwalks
# feelingofluxury
# newzealand.travelers
# foodirectory

# %%
driver.find_element(By.CLASS_NAME, '_aawn._9-lv').click()

# %% [markdown]
# Searching and Opening a profile using Open profile of “food_impramation”

# %%
driver.find_element(By.CLASS_NAME, '_aauy').send_keys("food_impramation")

# %%
result = driver.find_element(By.CLASS_NAME, '_abm4')
result.click()

# %% [markdown]
# Follow/Unfollow given handle -
#
# Open the Instagram Handle of “food_impramation”
#
# Start following it. Print a message if you are already following
#
# After following, unfollow the instagram handle. Print a message if you have already unfollowed.

# %%
follow_btn = driver.find_element(By.CLASS_NAME, '_acan._acap._acas._aj1-')
if follow_btn.text == 'Follow':
    follow_btn.click()
    print('Following')
else:
    print('You are already following this page !!')
# Out:
# Following

# %%
if driver.find_element(By.CLASS_NAME, '_aacl._aaco._aacw._aad6._aade').text == 'Follow':
    print('You have already unfollowed the page !!')
else:
    unfollow_btn = driver.find_element(By.CLASS_NAME, '_aacl._aaco._aacw._aad6._aade')
    unfollow_btn.click()
    pop_up = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div/div[7]')
    pop_up.click()
    print('Unfollowing')
# Out:
# Unfollowing

# %% [markdown]
# Like/Unlike posts:-
#
# Liking the top 30 posts of the ‘food_impramation'. Print message if you have already liked it.
#
# Unliking the top 30 posts of the ‘food_impramation’. Print message if you have already unliked it.

# %%
driver.execute_script("window.scrollBy(0, document.body.scrollHeight);")
driver.implicitly_wait(5)

post_list = driver.find_elements(By.CLASS_NAME, '_aagw')

for i in range(30):
    post_list[i].click()
    like_btn = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, '_aamw')))
    str = BeautifulSoup(like_btn.get_attribute("innerHTML"), 'html.parser').svg['aria-label']
    if str == 'Like':
        like_btn.click()
        print('Post liked')
    else:
        print('Post already liked')
    close = driver.find_element(By.CLASS_NAME, 'x1i10hfl.x6umtig.x1b1mbwd.xaqea5y.xav7gou.x9f619.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x16tdsg8.x1hl2dhg.xggy1nq.x1a2a7pz.x6s0dn4.x78zum5.xjbqb8w.x1ejq31n.xd10rxx.x1sy0etr.x17r0tee.x1ypdohk.xl56j7k.x1y1aw1k.x1sxyh0.xwib8y2.xurb0ha')
    close.click()
    time.sleep(2)
# Out:
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked
# Post liked

# %%
post_list = driver.find_elements(By.CLASS_NAME, '_aagw')

for i in range(30):
    post_list[i].click()
    like_btn = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, '_aamw')))
    str = BeautifulSoup(like_btn.get_attribute("innerHTML"), 'html.parser').svg['aria-label']
    if str == 'Unlike':
        like_btn.click()
        print('Post unliked')
    else:
        print('Post already unliked')
    close = driver.find_element(By.CLASS_NAME, 'x1i10hfl.x6umtig.x1b1mbwd.xaqea5y.xav7gou.x9f619.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x16tdsg8.x1hl2dhg.xggy1nq.x1a2a7pz.x6s0dn4.x78zum5.xjbqb8w.x1ejq31n.xd10rxx.x1sy0etr.x17r0tee.x1ypdohk.xl56j7k.x1y1aw1k.x1sxyh0.xwib8y2.xurb0ha')
    close.click()
    time.sleep(2)
# Out:
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked
# Post unliked

# %%
driver.back()
driver.refresh()

# %% [markdown]
# Extract list of followers
#
# Extract the usernames of the first 500 followers of ‘vellorefoodreviews’ and ‘food_impramation’.
#
# Now print all the followers of “food_impramation” that you are following but those who don’t follow you.

# %%
#first 500 followers of vellorefoodreviews
driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[1]/div/div/div/div[1]/div[1]/div[1]/div/div/div/div/div[2]/div[2]/div/a/div').click()
driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[1]/div/div/div/div[1]/div[1]/div[1]/div/div/div[2]/div/div/div[2]/div[1]/div/input').send_keys('vellorefoodreviews')

# %%
result = driver.find_element(By.CLASS_NAME, '_aacl._aaco._aacw._aacx._aad6')
result.click()

# %%
followers_btn = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[1]/div/div/div/div[1]/div[1]/div[2]/section/main/div/header/section/ul/li[2]/a')
followers_btn.click()

# %%
frame = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[2]')
for i in range(100):
    time.sleep(1)
    driver.execute_script("arguments[0].scrollTop=arguments[0].scrollHeight", frame)

# %%
followers = driver.find_elements(By.CLASS_NAME, '_ab8w._ab94._ab97._ab9f._ab9k._ab9p._ab9-._aba8._abcm')
names = []
for i in followers[:500] :
    names.append(i.text.split('\n')[0])
        
j = 1
for i in names:
    print(j, i)
    j += 1
# Out:
# 1 ____swetha.21
# 2 anjithaj
# 3 mayajohnny
# 4 appu_1640
# 5 sudarshan.mani.baskar
# 6 ashu_princess_01
# 7 thameem_thalapathy_67
# 8 balajigrisly
# 9 manigdamo
# 10 nizamano1
# 11 bala_rajendiran
# 12 parteykhawlhring
# 13 gopiv_62
# 14 agent_ash97
# 15 jawaharsimon87
# 16 life_of_thilks
# 17 sugar_and_spice29
# 18 maheswaranmaddy
# 19 rohit_kumar_98765
# 20 asha12786
# 21 insta_venkat.kumar
# 22 melody_drew_
# 23 ci.tmilll
# 24 santhoshrealestate
# 25 tn51_rishithan
# 26 7142amit
# 27 sur.singh.27
# 28 kxrthiiii__
# 29 aparnafelici
# 30 vijayprsanth
# 31 arshiya_fathimahaq
# 32 nafis_babu
# 33 little_meow_0412
# 34 thisgirleats2023
# 35 cr_dharsh_7
# 36 sus.hantx
# 37 vignesh22023
# 38 dhoronbuva
# 39 kitoos_appe
# 40 gowthu_gow
# 41 sensat19
# 42 mrblack_427
# 43 l___y__f
# 44 _._paras__garg_._
# 45 kumarsivakumar466
# 46 botsquad_3235
# 47 shrinidhi_55
# 48 jackarun.arun28
# 49 00.puneeth
# 50 mk09_09_
# 51 sri_sai_saraswathi_cards_vlr
# 52 gopi_sugir
# ...

# %%
driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[1]/div/div[3]/div/button').click()

# %%
#first 500 followers of food_impramation
driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[1]/div/div/div/div[1]/div[1]/div[1]/div/div/div/div/div[2]/div[2]/div/a/div').click()
driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[1]/div/div/div/div[1]/div[1]/div[1]/div/div/div[2]/div/div/div[2]/div[1]/div/input').send_keys('food_impramation')

# %%
result = driver.find_element(By.CLASS_NAME, '_aacl._aaco._aacw._aacx._aad6')
result.click()

# %%
follower_list_btn = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[1]/div/div/div/div[1]/div[1]/div[2]/section/main/div/header/section/ul/li[2]/a')
follower_list_btn.click()

# %%
frame = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[2]')
for i in range(100):
    time.sleep(1)
    driver.execute_script("arguments[0].scrollTop=arguments[0].scrollHeight", frame)

# %%
followers = driver.find_elements(By.CLASS_NAME, '_ab8w._ab94._ab97._ab9f._ab9k._ab9p._ab9-._aba8._abcm')
names = []
for i in followers[:500] :
    names.append(i.text.split('\n')[0])
    
j = 1
for i in names:
    print(j, i)
    j += 1
# Out:
# 1 _silent.__.eyes.__
# 2 sugusudhahari
# 3 _crazy._.sankaran._.ktp
# 4 gblopal
# 5 nesapriya_27
# 6 catlover56778
# 7 sathyanand96
# 8 joe_v_i_g_n_e_s_h
# 9 sunilrk03
# 10 arunps21
# 11 mr_optimus_prime_1023
# 12 kavitha6396
# 13 meenambikab2
# 14 promoth977
# 15 dhivamurali
# 16 raj_kumar_rajasekar
# 17 siva_naresh31
# 18 mentalist_hp
# 19 harini_prithiga
# 20 imxharish_18
# 21 magtalinaa
# 22 hemanthinweb
# 23 smart_stanger
# 24 paid_fun_soniya93
# 25 aravindlakshmanan_
# 26 prakhash007
# 27 anandhan_remo
# 28 _dark_d.evil_
# 29 _.adhikari_here._
# 30 me_subramani
# 31 mr_blade_
# 32 venki78272022
# 33 dharik_05
# 34 mageprofessor
# 35 _samyuktha_xx
# 36 its.sudhakar
# 37 ie_m_bharath
# 38 rv_darkdevil
# 39 ajithiyan_ismail
# 40 msb_basith
# 41 s.i.d.h.u_______
# 42 abeexh._
# 43 sai_prasaanth
# 44 twinkle_2_mingle
# 45 harigiri1997
# 46 chitra.sakthive
# 47 meena.prabha.75
# 48 ecuadorbarca
# 49 disco__cop__
# 50 shanthini_029
# 51 sigappi_chidambaram
# 52 chaat_ka_chatora
# ...

# %%
driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[1]/div/div[3]/div/button').click()

# %%
#followers of “food_impramation” that you are following but those who don’t follow you
driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[1]/div/div/div/div[1]/div[1]/div[1]/div/div/div/div/div[2]/div[2]/div/a/div').click()
driver.find_element(By.CLASS_NAME, '_aauy').send_keys('shibayan_biswas')

# %%
result = driver.find_element(By.CLASS_NAME, '_aacl._aaco._aacw._aacx._aad6')
result.click()

# %%
following_list_btn = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[1]/div/div/div/div[1]/div[1]/div[2]/section/main/div/header/section/ul/li[3]/a')
following_list_btn.click()

# %%
frame = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[3]')
for i in range(50):
    time.sleep(1)
    driver.execute_script("arguments[0].scrollTop=arguments[0].scrollHeight", frame)

# %%
#finding users whom I follow
following = driver.find_elements(By.CLASS_NAME, '_ab8w._ab94._ab97._ab9f._ab9k._ab9p._ab9-._aba8._abcm')
names_follow = []
for i in following :
    names_follow.append(i.text.split('\n')[0])

# %%
driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[1]/div/div[3]/div/button').click()

# %%
follower_list_btn = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[1]/div/div/div/div[1]/div[1]/div[2]/section/main/div/header/section/ul/li[2]/a')
follower_list_btn.click()

# %%
frame = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[2]')
for i in range(50):
    time.sleep(1)
    driver.execute_script("arguments[0].scrollTop=arguments[0].scrollHeight", frame)

# %%
#finding users who follow me
following = driver.find_elements(By.CLASS_NAME, '_ab8w._ab94._ab97._ab9f._ab9k._ab9p._ab9-._aba8._abcm')
follow_names = []
for i in following :
    follow_names.append(i.text.split('\n')[0])

# %%
driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[1]/div/div[3]/div/button').click()

# %%
names = set(names)
names_follow = set(names_follow)
follow_names = set(follow_names)

# %%
common_followers = names.intersection(names_follow)

if len(common_followers) == 0 :
    print('No such users found')
else:
    followers_common = common_followers.intersection(follow_names)
    if len(followers_common) == 0:
        print('No such users found')
    else:
        for user in followers_common:
            print(user)
# Out:
# No such users found

# %% [markdown]
# Check the story of ‘coding.ninjas’. Consider the following Scenarios and print error messages accordingly -
#
# If You have already seen the story.
#
# Or The user has no story.
#
# Or View the story if not yet seen.

# %%
# checking and verifying the status of the story of 'coding.ninjas'
driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[1]/div/div/div/div[1]/div[1]/div[1]/div/div/div/div/div[2]/div[2]/div/a/div').click()
driver.find_element(By.CLASS_NAME, '_aauy').send_keys('coding.ninjas')

# %%
result = driver.find_element(By.CLASS_NAME, '_aacl._aaco._aacw._aacx._aad6')
result.click()

# %%
story_btn = driver.find_element(By.XPATH, '//div[starts-with(@class,"_aarf")]')

if story_btn.get_attribute("aria-disabled") == "true":
    print("No story available")
else:
    story_check = driver.find_element(By.XPATH, '//div[starts-with(@class,"_aarf")]/canvas')
    if story_check.get_attribute("height") == '166':
        print("Story already seen")
    else:
        print("Seeing the story")
        story_view = driver.find_element(By.XPATH, '//div[starts-with(@class,"_aarf")]/span')
        story_view.click()
# Out:
# Seeing the story
