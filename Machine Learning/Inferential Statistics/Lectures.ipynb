# %% [markdown]
# ## Lecture - 1 (Introduction to Inferential Statistics)

# %% [markdown]
# In the last chapter, we have read about "Descriptive Statistics". It helps organize the data and focuses on main characteristics of data. It provides summary of data numerically.
#
# In this session, let's discuss about "Inferential Statistics". Inferential statistics is all about describing the larger picture of the analysis
# with a limited set of data and deriving conclusions from it.  Basically, inferential statistics aims at drawing conclusions on populations
# based on the taken data samples. It uses a random sample of data taken from a population to describe and make inferences about the population.

# %% [markdown]
# Inferential Statistics is used to draw inferences beyond the immediate data
# available. In inferential statistics we use methods that rely on probability theory and distribution helping us to predict, in particular, the population’s values based on sample data. Inferential statistics helps us answer the following questions:
#
# • Making inferences about a population from a sample
#
# • Concluding whether a sample is significantly different from the population

# %% [markdown]
# ![Inferential-Statistics.jpg](attachment:Inferential-Statistics.jpg)

# %% [markdown]
# #### There are two main areas of inferential statistics :
#
# • Estimating parameters - Taking a statistic from your sample data (for example the sample mean) and using it to find something about a population parameter (i.e. the population mean).
#
# • Hypothesis tests - Using sample data to answer research questions. For example, finding if a new cancer drug is effective or not, if breakfast helps children perform better in schools, etc.

# %% [markdown]
# #### Prerequisites for understanding Inferential Statistics :
#
# • Descriptive Statistics
#
# • Probability
#
# • Probability Distributions

# %% [markdown]
# ## Lecture - 2 (Probablity Distribution)

# %% [markdown]
# In statistics, with distribution we usually mean probability distribution. A probability distribution is a function that shows the possible values for a variable and how often they occur.
#
# #### Types of data :
#
# • Discrete - Can take only specified values. For example : The outcomes obtained when we roll a die.
#
# • Continuous - Can take any value within a given range. For example : Height/Weight of students studying in a school.
#
# #### Terminologies :
#
# • Random Variable - Whose value is determined by the outcome of a random experiment
#
# • Discrete random variable - Whose set of assumed values is countable (arises from counting)
#
# • Continuous random variable - Whose set of assumed values is uncountable (arises from measurement)

# %% [markdown]
# A probability distribution is a list of all of the possible outcomes of a random variable along with their corresponding probability values. For eg. rolling a dice, tossing a coin, measuring weight of a student etc.

# %% [markdown]
# #### Kind of variable determines the type of probability distribution :
#
# • Discrete probability distributions for discrete variables
#
# • Probability density functions for continuous variables

# %% [markdown]
# #### Discrete Probability Distribution :
#
# It is also known as Probability Mass Function. For example : coin tosses, rolling a dice, etc. Each possible value has a non-zero likelihood. The probabilities for all possible values must sum to one. There are a variety of discrete probability distributions that you can use to model different types of data. The correct discrete distribution depends on the properties of your data. Let's have a look into the types of Discrete Distribution :
#
# • **Binomial distribution** - It summarizes the likelihood that a value will take one of two independent values under a given set of parameters or assumptions.
#
# • **Poisson distribution** - It can be used to estimate how many times an event is likely to occur within fixed periods of time. It gives the probability of a discrete outcomes and can only take whole number values with no fractions or decimals.
#
# • **Uniform distribution**
#
# For example, let's see the Probablity Distributions for rolling one, two, three and four dice :

# %% [markdown]
# ![Screenshot%202023-04-19%20184207.png](attachment:Screenshot%202023-04-19%20184207.png)

# %% [markdown]
# #### Continious Probablity Distribution :
#
# It is also known as Probability Density Function. For example - often measurements on a scale, such as height, weight, and
# temperature. Specific values in continuous distributions have a zero probability. For example, the likelihood of measuring a temperature that is exactly 32 degrees is zero (because an individual value has an infinitesimally small probability that is equivalent to zero).
#
# Probabilities for continuous distributions are measured over ranges of values rather than single points. A probability indicates the likelihood that a value will fall within an interval. On a probability plot, the entire area under the distribution curve equals 1. This fact is equivalent to how the sum of all probabilities must equal one for discrete distributions. The most well-known continuous distribution is the **Normal Distribution**.

# %% [markdown]
# ## Lecture - 3 (Normal Distribution)

# %% [markdown]
# A normal distribution is the most common and widely used distribution in statistics because it approximates to a wide variety of random variables. It is also called a "bell curve" and "Gaussian curve".

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Characteristics of  Normal Distribution :
#
# • Mean = Median = Mode
#
# • It is symmetric, perfectly centred around mean.
#
# • The area under the curve is 1.
#
# • The entire family of normal distribution is differentiated by two parameters - Mean and Standard Deviation.
#
# • It is denoted as - N ~ (μ, σ²), where μ = the mean, σ = the standard deviation.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Standared Normal Distribution :
#
# The standard normal distribution is a special case of the normal distribution when a normal random variable has a mean of 0 and a standard deviation of 1.
#
# So if we shift the mean by μ and the standard deviation by σ for any normal distribution we will arrive at the standard normal distribution. We use the letter "z" to denote it, where z = (x - μ)/σ
#
# ![image.png](attachment:image.png)
#
# The normal random variable of a standard normal distribution is called a standard score or a Z-score.

# %% [markdown]
# #### Why do we need standard Normal Distribution :
#
# • Makes predictions and inferences much easier
#
# • Compare different normally distributed datasets
#
# • Detect normality
#
# • Detect outliers
#
# • Create confidence intervals
#
# • Test Hypothesis

# %% [markdown]
# ## Lecture - 4 (Sampling Distribution)

# %% [markdown]
# A Sampling Distribution is a probability distribution of a statistic obtained through a large number of samples drawn from a specific population.
#
# For example, consider a normal population with mean µ and variance σ. Assume we repeatedly take samples (using Simple Random Sampling) of a given size from this population and calculate the arithmetic mean for each sample. This statistic is then called the sample mean. Each sample has its own average value, and the distribution of these averages is called the "Sampling Distribution" of the sample mean.

# %% [markdown]
# Now we can actually see this with the help of python code. Here I have downloaded the file "weight-height.csv" and I will be finding out the "Sampling Distribution" of the dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statistics

# %%
# loading the dataset
data = pd.read_csv('weight-height.csv')
data
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %% [markdown]
# So first of all, I am trying to find out the average for the population. Currently, I am interested in working over the column "Height". So, the complete column "Height" is "Population" for me which is having 10 thousand values. Now I need to extract some sample out of it.

# %%
# getting the average value of the "Population"
data['Height'].mean()
# Out:
# 66.36755975482106

# %%
# extracting sample (of size = 50) from the "Population" using "Simple Random Sampling" algorithm
sample = data['Height'].sample(n = 50)

# getting the average value of the "Sample"
sample.mean()
# Out:
# 66.2147947684944

# %% [markdown]
# Here we can see that the "Sample's mean" is not exactly the same as the "Population's mean", although it is quite similar.
#
# Every time we select a "Sample" from the "Population" and find it's mean, we get a different value which is not exactly the same as the mean of the "Population".
#
# We need to extract large number of "Sample" from the "Population", in order to to find the Sampling Distribution.

# %%
# list to store the means of the samples (1,000 values it should store)
sample_mean = []

# extracting large number of "Sample" from the "Population" (for example : 1,000 samples)
for i in range(1, 1000):
    
    # extracting samples (of size = 50) where every sample will be having it's different mean
    sample = data['Height'].sample(n = 50)
    
    # getting the average value of each sample and appending it to the list
    sample_mean.append(sample.mean())

# %% [markdown]
# Now, if we a draw a distribution using the list (containing the means of 1,000 "Sample" selected from the "Population"), the distribution will be termed as a Sampling Distribution.

# %%
# For the distribution, let's try to plot a histogram for the list (containing the means of 1,000 "Sample" selected from the "Population")
plt.hist(sample_mean, bins = 20)
plt.show()

# %% [markdown]
# The plot obtained is the Sampling Distribution of the cloumn "Height", of the dataset "weight-height.csv".
#
# A Sampling Distribution behaves much like a Normal Distribution. It can be a perfect Normal Distribution if we increase the "Sample Size" and the "Sample Number". It has some interesting properties like :
#
# • The shape of the Sampling Distribution does not reveal anything about the shape of the population.
#
# • Sampling Distribution helps to estimate the population statistic, using Central Limit Theorem

# %%
# plotting the "Population Distribution"
plt.hist(data['Height'], bins = 20)
plt.show()

# %% [markdown]
# Here the "Population Distribution" looks like a Normal Distribution, but it is not always necessary. The Sampling Distribution behaves much like a Normal Distribution.

# %% [markdown]
# ## Lecture - 5 (Central Limit Theorem)

# %% [markdown]
# Sampling distribution can be very useful in making inferences about the overall population. To find how much sample means differ from each other, we’ll use standard deviation of the Sampling Distribution. This standard deviation is called the standard error.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# where,
#
# **s** : Sample Statistic (Sample Mean)
#
# **n** : Sample Size

# %% [markdown]
# #### Central Limit Theorem (given that sample size >= 30) :
#
# • The sampling distribution of the sample mean has an approximately normal distribution.
#
# • The mean of the sampling distribution is equals to the population mean.
#
# • The standard deviation of the sampling distribution equals the standard deviation in the population divided by the square root of the sample size (i.e. standard error).

# %% [markdown]
# #### Poperties of Central Limit Theorem :
#
# • Central Limit Theorem holds true irrespective of the type of distribution of the population.
#
# • Now, we have a way to estimate the population mean by just making repeated observations of samples of a fixed size.
#
# • Greater the sample size, lower the standard error and greater accuracy in determining the population mean from the sample mean.

# %% [markdown]
# #### Significance of Central Limit Theorem :
#
# • Analyzing data involves statistical methods like hypothesis testing and constructing confidence intervals. These methods assume that the population is normally distributed. In case of
# unknown or non-normal distributions, we treat the sampling distribution as normal according to the central limit theorem.
#
# • If we increase the samples drawn from the population, the standard deviation of sample means will decrease. This helps us estimate the population mean much more accurately.

# %% [markdown]
# • The central limit theorem gives a formula for the sample mean and the sample standard deviation when the population mean and standard deviation are known. This is given as follows :
#
# Sample mean = Population mean
#
# Sample standard deviation = (Population standard deviation) / √n = σ / √n.
