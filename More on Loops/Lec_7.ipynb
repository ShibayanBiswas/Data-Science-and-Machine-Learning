# %%
n = int(input())
for i in range(2, n + 1, 2):
    if i % 7 == 0:
        continue
    print(i)
# Out:
# 100
# 2
# 4
# 6
# 8
# 10
# 12
# 16
# 18
# 20
# 22
# 24
# 26
# 30
# 32
# 34
# 36
# 38
# 40
# 44
# 46
# 48
# 50
# 52
# 54
# 58
# 60
# 62
# 64
# 66
# 68
# 72
# 74
# 76
# 78
# 80
# 82
# 86
# 88
# 90
# 92
# 94
# 96
# 100

# %%
n = int(input())
for i in range(2, n + 1, 2):
    print(i)
    if i % 7 == 0:
        continue
    print(i)
# Out:
# 100
# 2
# 2
# 4
# 4
# 6
# 6
# 8
# 8
# 10
# 10
# 12
# 12
# 14
# 16
# 16
# 18
# 18
# 20
# 20
# 22
# 22
# 24
# 24
# 26
# 26
# 28
# 30
# 30
# 32
# 32
# 34
# 34
# 36
# 36
# 38
# 38
# 40
# 40
# 42
# 44
# 44
# 46
# 46
# 48
# 48
# 50
# 50
# 52
# 52
# 54
# 54
# 56
# 58
# 58
# 60
# 60
# 62
# 62
# 64
# 64
# 66
# 66
# 68
# 68
# 70
# 72
# 72
# 74
# 74
# 76
# 76
# 78
# 78
# 80
# 80
# 82
# 82
# 84
# 86
# 86
# 88
# 88
# 90
# 90
# 92
# 92
# 94
# 94
# 96
# 96
# 98
# 100
# 100

# %%
n = int(input())
i = 2
while i <= n:
    if i % 7 == 0:
        i = i + 2
        continue
    print(i)
    i = i + 2
# Out:
# 100
# 2
# 4
# 6
# 8
# 10
# 12
# 16
# 18
# 20
# 22
# 24
# 26
# 30
# 32
# 34
# 36
# 38
# 40
# 44
# 46
# 48
# 50
# 52
# 54
# 58
# 60
# 62
# 64
# 66
# 68
# 72
# 74
# 76
# 78
# 80
# 82
# 86
# 88
# 90
# 92
# 94
# 96
# 100
